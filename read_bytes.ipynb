# %%
with open(r'C:\Users\Patrick\OneDrive - UNSW\Desktop\CTDev_PPHR1_10_1_25mm_dH_r1\tomo_R_LoRes.nc', "rb") as f:
    # f.readlines(1)
    # f.readlines(1)
    f.readlines(1)
    byte = f.readlines(1)

# %%
byte
# Out:
# [b'\x00\x00\x00\x05\x00\x00\x00\ttomo_zdim\x00\x00\x00\x00\x00\x03f\x00\x00\x00\ttomo_ydim\x00\x00\x00\x00\x00\x02v\x00\x00\x00\ttomo_xdim\x00\x00\x00\x00\x00\x02v\x00\x00\x00\x0bmd5sums_dim\x00\x00\x00\x00\x10\x00\x00\x00\x12data_histogram_dim\x00\x00\x00\x00\x921\x00\x00\x00\x0c\x00\x00\x00\x16\x00\x00\x00\n']

# %%
"zdim" not in str(byte)
# Out:
# False

# %%
counter = 0
with open(r'C:\Users\Patrick\OneDrive - UNSW\Desktop\CTDev_PPHR1_3_3_25mm_dH\tomo_R_LoRes.nc', "rb") as f:
    byte = f.readlines(1)
    print(byte)
    while "md5_checksum" not in str(byte):
    # for i in range(670):
        byte = f.readlines(1)
        counter+=1
        print(byte)
    print(byte)
    print(counter)
# Out:
# [b'CDF\x01\x00\x00\x00\x00\x00\x00\x00\n']
# [b'\x00\x00\x00\x05\x00\x00\x00\ttomo_zdim\x00\x00\x00\x00\x00\x03H\x00\x00\x00\ttomo_ydim\x00\x00\x00\x00\x00\x02v\x00\x00\x00\ttomo_xdim\x00\x00\x00\x00\x00\x02v\x00\x00\x00\x0bmd5sums_dim\x00\x00\x00\x00\x10\x00\x00\x00\x12data_histogram_dim\x00\x00\x00\x00ry\x00\x00\x00\x0c\x00\x00\x00\x16\x00\x00\x00\n']
# [b'zdim_total\x00\x00\x00\x00\x00\x04\x00\x00\x00\x01\x00\x00\x03H\x00\x00\x00\x0fnumber_of_files\x00\x00\x00\x00\x04\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00\n']
# [b'zdim_range\x00\x00\x00\x00\x00\x04\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x03G\x00\x00\x00\x10data_description\x00\x00\x00\x02\x00\x00\x00(Raw reconstructed tomogram data <ushort>\x00\x00\x00\x0evoxel_size_xyz\x00\x00\x00\x00\x00\x05\x00\x00\x00\x03=/\xea)=/\xea)=/\xea)\x00\x00\x00\n']
# [b'voxel_unit\x00\x00\x00\x00\x00\x02\x00\x00\x00\x02mm\x00\x00\x00\x00\x00\x0fcoord_transform\x00\x00\x00\x00\x02\x00\x00\x00\x01\n']
# ...

# %%
counter = 0
with open(r'C:\Users\Patrick\OneDrive - UNSW\Desktop\CTDev_PPHR1_10_1_25mm_dH_r1\tomo_R_LoRes.nc', "rb") as f:
    byte = f.read(1)
    # print(byte)
    # while byte != r"b'C'":
    for i in range(30560):
        # Do stuff with byte.
        counter+=1
        print(byte)

        # print(counter)
        byte = f.read(1)
# Out:
# b'C'
# b'D'
# b'F'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\n'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x05'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\t'
# b't'
# b'o'
# b'm'
# b'o'
# b'_'
# b'z'
# b'd'
# b'i'
# b'm'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x03'
# b'f'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\t'
# b't'
# b'o'
# b'm'
# b'o'
# b'_'
# b'y'
# b'd'
# b'i'
# b'm'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x02'
# b'v'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\t'
# b't'
# b'o'
# b'm'
# b'o'
# b'_'
# b'x'
# b'd'
# b'i'
# b'm'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x02'
# b'v'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x0b'
# b'm'
# b'd'
# b'5'
# b's'
# b'u'
# b'm'
# b's'
# b'_'
# b'd'
# b'i'
# b'm'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x10'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x12'
# b'd'
# b'a'
# b't'
# b'a'
# b'_'
# b'h'
# b'i'
# b's'
# b't'
# b'o'
# b'g'
# b'r'
# b'a'
# b'm'
# b'_'
# b'd'
# b'i'
# b'm'
# b'\x00'
# ...

# %%
bytes = b"\x00\x00\x00\x00\x00\x0cdata_min_max\x00\x00\x00\x06\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00@\xdc\x9e\x00\x00\x00\x00\x00\x00\x00\x00\x16data_histogram_binsize\x00\x00\x00\x00\x00\x06\x00\x00\x00\x01?\xf0\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15data_histogram_offset\x00\x00\x00\x00\x00\x00\x06\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0b\x00\x00\x00\x03\x00\x00\x00\x0cmd5_checksum\x00\x00\x00\x01\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x10\x00\x00t\x80\x00\x00\x00\x04tomo\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03'\xbep@\x00\x00t\x90\x00\x00\x00\x0edata_histogram\x00\x00\x00\x00\x00\x01\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x06\x00\x03\x93\xc8'\xbe\xe4\xd0\x8a$\x90\xe8(v\x80)ro\xb9\xedry\xca'\t\xc9\t\xb4\x0e\x99\x13t\x13\x89\x1d>\x1d\x0e\x1d.&\xfc&\xef'\x08')'4',&\xfd'\x11&\xdd'.&\xdf&\xee'\x0b''&\xf8&\xf8'\x07'''\x0e&\xfe'''\x18&\xed&\xd2''&\xf8&\xf2&\xfd'\x1a'\x06&\xe6&\xe0&\xfb'\x14&\xd2&\xf6'\x15&\xfd&\xee'4&\xf4'!&\xfe'\x1f'\x07' &\xfb'\x0b&\xe5&\xf3\x1f\xd0\x1dT\x1dc\x16\x08\x13\x81\x11*\t\xcb\t\xc2\x02u\t\xc8\x0e\xa8\x13w\x18P\x1dD\x1f\xcb'&'\n"

# %%
a = list(b'\x00\x00\x00\x06\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00@\xdc\x9e\x00\x00\x00\x00\x00\x00\x00\x00\x16')
print(a)
# Out:
# [0, 0, 0, 6, 0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 0, 64, 220, 158, 0, 0, 0, 0, 0, 0, 0, 0, 22]
